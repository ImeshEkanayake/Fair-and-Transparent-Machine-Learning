# %%
import os
import cv2
import h5py
import json
import keras
import random 
import imageio
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import plotly.express as px
from keras import backend as K
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Data = pd.read_csv('/content/drive/My Drive/donorschoose/Stat_Data.csv') 
Data.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#    Unnamed: 0  ... Donation Included Optional Donation
# 0           0  ...                                  No
# 1           1  ...                                 Yes
# 2           2  ...                                 Yes
# 3           3  ...                                 Yes
# 4           4  ...                                 Yes
#
# [5 rows x 26 columns]

# %%
Data.describe()
# Out:
#          Unnamed: 0  ...  School Percentage Free Lunch
# count  4.608080e+06  ...                  4.586186e+06
# mean   2.304040e+06  ...                  6.444936e+01
# std    1.330238e+06  ...                  2.518006e+01
# min    0.000000e+00  ...                  0.000000e+00
# 25%    1.152020e+06  ...                  4.700000e+01
# 50%    2.304040e+06  ...                  7.000000e+01
# 75%    3.456059e+06  ...                  8.600000e+01
# max    4.608079e+06  ...                  1.000000e+02
#
# [8 rows x 7 columns]

# %%
statistical_var=["Donation ID","Project ID","Donor ID","School ID","Teacher ID","Donation Amount",
                 "Project Cost","Project Type","Project Subject Category Tree","Project Subject Subcategory Tree",
                 "Project Grade Level Category","Project Resource Category","Teacher Project Posted Sequence",
                 "Donor Zip","Donor City","Donor State","Donor Cart Sequence","Donor Is Teacher",
                 "Project Current Status","School Metro Type","School Zip","School State","Teacher Prefix",
                 "School Percentage Free Lunch","Donation Included Optional Donation"]
